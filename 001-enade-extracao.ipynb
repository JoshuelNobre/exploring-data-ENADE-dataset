# %% [markdown]
# # Extração os dados do Enade

# %%
# Impotar bibliootecas necessárias
import pandas as pd
import numpy as np
import zipfile
import requests
from io import BytesIO
import os
import glob
import dask.dataframe as dd
import dask.bag as db

# %%
# Criar um diretório para armazenar oo conteúdo doo ENADE
# exist_ok = se a pasta já existir não vai gerar erro
os.makedirs('../001-fundamentos/enade2019', exist_ok=True)

# %%
# # Não vou usar isso pois os dados estão quebrado, então baixei pelo kaggle mesmo
# Link do kaggle: https://www.kaggle.com/datasets/joaoavf/inep-microdados-enade-2018/download?datasetVersionNumber=1
# # Define a url
# url = r'https://download.inep.gov.br/microdados/microdados_enade_2019_LGPD.zip'

# # Faz o download do conteúdo
# filebytes = BytesIO(
#     requests.get(url, verify=False).content
# )

# # Extrair oo conteúdo do zipfile
# myzip = zipfile.ZipFile(filebytes)
# myzip.extractall("../001-fundamentos/enade2019")

# %% [markdown]
# ## Verificando os dados baixados

# %%
enade = pd.read_csv("../001-fundamentos/enade2019/2018/3.DADOS/microdados_enade_2018.txt",
                   sep=';', decimal =',')

# %%
enade
# Out:
#         NU_ANO  CO_IES  CO_CATEGAD  CO_ORGACAD  CO_GRUPO  CO_CURSO  \
# 0         2018    1356       10003       10020         1     47116
# 1         2018    1356       10003       10020         1     47116
# 2         2018    1356       10003       10020         1     47116
# 3         2018    1356       10003       10020         1     47116
# 4         2018    1356       10003       10020         1     47116
# ...        ...     ...         ...         ...       ...       ...
# 548122    2018    1723       10008       10022        13   1105114
# 548123    2018    1201       10005       10022        22     50787
# 548124    2018    1201       10005       10022         1     18795
# 548125    2018    1201       10005       10022        22     50787
# 548126    2018    1201       10005       10022        22     50787
#
#         CO_MODALIDADE  CO_MUNIC_CURSO  CO_UF_CURSO  CO_REGIAO_CURSO  ...  \
# 0                   1         3546603           35                3  ...
# ...

# %%
enade.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548127 entries, 0 to 548126
# Columns: 137 entries, NU_ANO to QE_I68
# dtypes: float64(62), int64(33), object(42)
# memory usage: 572.9+ MB

# %%
dict(enade.dtypes)
# Out:
# {'NU_ANO': dtype('int64'),
#  'CO_IES': dtype('int64'),
#  'CO_CATEGAD': dtype('int64'),
#  'CO_ORGACAD': dtype('int64'),
#  'CO_GRUPO': dtype('int64'),
#  'CO_CURSO': dtype('int64'),
#  'CO_MODALIDADE': dtype('int64'),
#  'CO_MUNIC_CURSO': dtype('int64'),
#  'CO_UF_CURSO': dtype('int64'),
#  'CO_REGIAO_CURSO': dtype('int64'),
#  'NU_IDADE': dtype('int64'),
#  'TP_SEXO': dtype('O'),
#  'ANO_FIM_EM': dtype('int64'),
#  'ANO_IN_GRAD': dtype('float64'),
#  'CO_TURNO_GRADUACAO': dtype('float64'),
#  'TP_INSCRICAO_ADM': dtype('int64'),
#  'TP_INSCRICAO': dtype('int64'),
#  'NU_ITEM_OFG': dtype('int64'),
#  'NU_ITEM_OFG_Z': dtype('int64'),
#  'NU_ITEM_OFG_X': dtype('int64'),
#  'NU_ITEM_OFG_N': dtype('int64'),
#  'NU_ITEM_OCE': dtype('int64'),
#  'NU_ITEM_OCE_Z': dtype('int64'),
#  'NU_ITEM_OCE_X': dtype('int64'),
#  'NU_ITEM_OCE_N': dtype('int64'),
#  'DS_VT_GAB_OFG_ORIG': dtype('O'),
#  'DS_VT_GAB_OFG_FIN': dtype('O'),
#  'DS_VT_GAB_OCE_ORIG': dtype('O'),
# ...
